# %% [markdown]
# <a href="https://colab.research.google.com/github/MSJahnavi/InnovixionTech-Nov/blob/main/Task3_TodoList.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class ToDoList:
    def __init__(self):
        self.tasks = []

    def display_tasks(self):
        if not self.tasks:
            print("\033[1;31mNo tasks in the to-do list.\033[0m")  # Bold red text
        else:
            print("\033[1;34mTasks:\033[0m")  # Bold blue text
            for i, task in enumerate(self.tasks, start=1):
                print(f"\033[1;35m{i}. {task}\033[0m")  # Bold pink text

    def add_task(self, task):
        self.tasks.append(task)
        print(f"\033[1;35mTask '{task}' added successfully.\033[0m")  # Bold pink text

    def delete_task(self, task_number):
        try:
            task_number = int(task_number)
            if 1 <= task_number <= len(self.tasks):
                deleted_task = self.tasks.pop(task_number - 1)
                print(f"\033[1;31mTask '{deleted_task}' deleted successfully.\033[0m")  # Bold red text
            else:
                print("\033[1;31mInvalid task number. Please try again.\033[0m")  # Bold red text
        except ValueError:
            print("\033[1;31mInvalid input. Please enter a valid task number.\033[0m")  # Bold red text

    def edit_task(self, task_number, new_task):
        try:
            task_number = int(task_number)
            if 1 <= task_number <= len(self.tasks):
                self.tasks[task_number - 1] = new_task
                print(f"\033[1;36mTask {task_number} edited successfully.\033[0m")  # Bold cyan text
            else:
                print("\033[1;31mInvalid task number. Please try again.\033[0m")  # Bold red text
        except ValueError:
            print("\033[1;31mInvalid input. Please enter a valid task number.\033[0m")  # Bold red text

def main():
    todo_list = ToDoList()

    while True:
        print("\n1. Display Tasks")
        print("2. Add Task")
        print("3. Delete Task")
        print("4. Edit Task")
        print("5. Exit")

        choice = input("Enter your choice (1-5): ")

        if choice == '1':
            todo_list.display_tasks()
        elif choice == '2':
            task = input("Enter the task: ")
            todo_list.add_task(task)
        elif choice == '3':
            task_number = input("Enter the task number to delete: ")
            todo_list.delete_task(task_number)
        elif choice == '4':
            task_number = input("Enter the task number to edit: ")
            new_task = input("Enter the new task: ")
            todo_list.edit_task(task_number, new_task)
        elif choice == '5':
            print("\033[1;33mExiting the to-do list application. Goodbye!\033[0m")  # Bold yellow text
            break
        else:
            print("\033[1;31mInvalid choice. Please enter a valid option (1-5).\033[0m")  # Bold red text

if __name__ == "__main__":
    main()
# Out:
# 1. Display Tasks
# 2. Add Task
# 3. Delete Task
# 4. Edit Task
# 5. Exit
# Enter your choice (1-5): 1
# No tasks in the to-do list.
#
# 1. Display Tasks
# 2. Add Task
# 3. Delete Task
# 4. Edit Task
# 5. Exit
# Enter your choice (1-5): 2
# Enter the task: complete task3
# Task 'complete task3' added successfully.
#
# 1. Display Tasks
# 2. Add Task
# 3. Delete Task
# 4. Edit Task
# 5. Exit
# Enter your choice (1-5): 2
# Enter the task: apply for certification course
# Task 'apply for certification course' added successfully.
#
# 1. Display Tasks
# 2. Add Task
# 3. Delete Task
# 4. Edit Task
# 5. Exit
# Enter your choice (1-5): 1
# Tasks:
# 1. complete task3
# 2. apply for certification course
#
# 1. Display Tasks
# 2. Add Task
# 3. Delete Task
# 4. Edit Task
# 5. Exit
# Enter your choice (1-5): 4
# Enter the task number to edit: 2
# Enter the new task: apply for internship
# Task 2 edited successfully.
#
# 1. Display Tasks
# 2. Add Task
# 3. Delete Task
# 4. Edit Task
# 5. Exit
# ...
